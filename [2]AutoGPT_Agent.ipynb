# %% [markdown]
# ### 2. AutoGPT
# * 다음은 AutoGPT라는 에이전트를 ‘코드 멘토’로 활용하는 예제입니다. 그럼 바로 구현 방법에 대해 알아보겠습니다.
# * 다음 코드는 현재 디렉터리 안에 Auto-GPT라는 새 디렉터리를 생성하여 GitHub URL에 있는 저장소(repository)를 복사하라는 의미입니다.

# %%
# !git clone https://github.com/Significant-Gravitas/Auto-GPT.git

# %%
# %cd Auto-GPT

# %%
# !git tag -l

# %%
# !git checkout tags/v0.4.7

# %%
pip install -r requirements.txt

# %%
# !./run.sh
